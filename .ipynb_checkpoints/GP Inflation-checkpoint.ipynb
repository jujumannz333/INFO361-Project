# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
# os.chdir('D:\\Professional\\UNI 23-S2\\INFO361\\Group_project')
# Load data
median_income_df = pd.read_csv('median_income.csv') 
inflation_df = pd.read_csv('inflation.csv')  

merged_df = pd.merge(median_income_df, inflation_df, on='Year')

# Calculate the inflated cost of living
original_income = 480  # Original median household income per week
merged_df['Inflated_Cost'] = original_income * (1 + merged_df['Inflation'] / 100).cumprod()

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(merged_df['Year'], merged_df['Income'], label='Median Income', color='blue')
plt.plot(merged_df['Year'], merged_df['Inflated_Cost'], label='Inflated Cost of Living', color='red')
plt.xlabel('Year')
plt.ylabel('Amount ($)')
plt.title('Median Income vs Inflated Cost of Living')
plt.legend()
plt.grid(True)
plt.show()

# %%
print(median_income_df.columns)
print(inflation_df)
# Out:
# Index(['Year', 'Income'], dtype='object')
#     Year  Inflation
# 0   2008        4.0
# 1   2009        1.9
# 2   2010        1.7
# 3   2011        5.3
# 4   2012        1.0
# 5   2013        0.7
# 6   2014        1.6
# 7   2015        0.4
# 8   2016        0.4
# 9   2017        1.7
# 10  2018        1.5
# 11  2019        1.7
# 12  2020        1.5
# 13  2021        3.3
# 14  2022        7.3
# 15  2023        6.0

# %%
import warnings
warnings.filterwarnings('ignore')  # Suppress warnings

# Filter the inflation_df DataFrame to include only rows where 'Year' is between 2013 and 2023, inclusive.
filtered_inflation_df = inflation_df[(inflation_df['Year'] >= 2013) & (inflation_df['Year'] <= 2023)].copy()

# Calculate the cumulative product of inflation
filtered_inflation_df.loc[:, 'Cumulative_Inflation'] = (1 + filtered_inflation_df['Inflation'] / 100).cumprod()

# Plotting
plt.figure(figsize=(10, 6))

# Create an axis object
ax1 = plt.gca()

# Plotting Cumulative Inflation on the left y-axis
ax1.plot(filtered_inflation_df['Year'], filtered_inflation_df['Cumulative_Inflation'], color='purple', marker='o', label='Cumulative Inflation')
ax1.set_xlabel('Year')
ax1.set_ylabel('Cumulative Inflation (Times Factor Increase)')
ax1.tick_params(axis='y', labelcolor='purple')
ax1.legend(loc='upper left')

# Create a second y-axis for the flat inflation rate
ax2 = ax1.twinx()
ax2.plot(filtered_inflation_df['Year'], filtered_inflation_df['Inflation'], color='green', marker='s', linestyle='dashed', label='Flat Inflation Rate (%)')
ax2.set_ylabel('Flat Inflation Rate (%)', rotation=270, labelpad=15)
ax2.tick_params(axis='y', labelcolor='green')
ax2.legend(loc='upper right')

# Formatting
plt.title('Cumulative CPI Inflation and Flat CPI Inflation Rate from 2013 to 2023')
plt.grid(True)
plt.xticks(filtered_inflation_df['Year'], rotation=45)  # Rotate x-axis labels for better readability, if needed.
plt.tight_layout()  # Adjust layout for better readability, if needed.
plt.show()

# %%
# Getting the government funding / benefit data
# avg_benefit_df = pd.read_csv('avg-govt-income-mlr.csv')

# %%
# from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import OneHotEncoder
# myohe = OneHotEncoder()
# mytransformed = myohe.fit_transform(avg_benefit_df[['Ethnic Group']])
# # print(mytransformed.toarray())
# print(myohe.categories_)

# %%
# avg_benefit_df[myohe.categories_[0]] = mytransformed.toarray()
# avg_benefit_df

# %%
# # x = avg_benefit_df.loc[:, ["European", "Maori", "Pacific", "Asian", "MELAA", "Other"]]
# # y = avg_benefit_df.loc[:, "Year"]
# x = avg_benefit_df.loc[:, ["Asian", "European", "MELAA", "Maori", "Other", "Pacific Peoples"]]
# y = avg_benefit_df.loc[:, "Average Weekly Government Transfer Income"]

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression

# x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1) 

# myMLRmodel=LinearRegression()
# myMLRmodel.fit(x_train, y_train)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Trying again with better data

mydf = pd.read_csv('detailed-income.csv')

# %%
mydf = mydf.drop(['Region', 'Sex'], axis=1)

# %%
mydf.columns
# Out:
# Index(['Year', 'Income Source', 'Ethnic Group', 'Measure', 'Value', 'Flags'], dtype='object')

# %%
mydf.Measure.unique()
# Out:
# array(['Average Weekly Income', 'Median Weekly Income',
#        'Number of People (000)'], dtype=object)

# %%
mydf['Income Source'].unique()
# Out:
# array(['Self-employment Income', 'Wage and Salary Income',
#        'Government Transfer Income', 'All sources collected'],
#       dtype=object)

# %%
mydf['Ethnic Group'].unique()
# Out:
# array(['Total Ethnic Groups', 'European', 'Maori', 'Pacific Peoples',
#        'Asian', 'MELAA', 'Other Ethnicity'], dtype=object)

# %%
# # print(mydf['Value'] if mydf['Income Source'].value == "Self-employment Income")
# all_incomes = mydf.loc[mydf['Measure'] == 'Average Weekly Income', 'Value']
# govt_incomes = mydf.loc[(mydf['Income Source'] == 'Government Transfer Income') & (mydf['Measure'] == 'Average Weekly Income'), 'Value']
# # Define the dependent variable as 'Value' (Average Weekly Income)
# dependent_variable = 'Value'

# number_of_people = mydf.loc[mydf['Measure'] == 'Number of People (000)', 'Value']
# # print(number_of_people)
# # Define the independent variables
# independent_variables = ['Year', 'Income Source', 'Ethnic Group', 'Measure']

# # Perform one-hot encoding for categorical variables
# mydf_encoded = pd.get_dummies(mydf, columns=['Income Source', 'Ethnic Group', 'Measure'], drop_first=True)
# # print(mydf_encoded)
# # Split the data into training and testing sets
# train_data, test_data = train_test_split(mydf_encoded, test_size=0.2, random_state=42)

# # Create and fit the multiple linear regression model
# X_train = train_data.drop(columns=[dependent_variable])
# y_train = train_data[dependent_variable]
# model = LinearRegression()
# model.fit(X_train, y_train)

# # Make predictions on the testing data
# X_test = test_data.drop(columns=[dependent_variable])
# y_test = test_data[dependent_variable]
# y_pred = model.predict(X_test)

# # print(y_test)

# # Evaluate the model's performance
# mse = mean_squared_error(y_test, y_pred)
# rmse = mse**0.5
# print(f"Root Mean Squared Error: {rmse}")

# %%
govt_incomes = mydf.loc[(mydf['Income Source'] == 'Government Transfer Income') & (mydf['Measure'] == 'Average Weekly Income'), 'Value']
govt_incomes
# Out:
# 66     284.0
# 67     286.0
# 68     297.0
# 69     304.0
# 70     314.0
#        ...
# 864    346.0
# 865    367.0
# 866    405.0
# 867    409.0
# 868    424.0
# Name: Value, Length: 77, dtype: float64

# %%
# Wrangling the data

# Split the Measure column into Median weekly, Avg weekly incomes, and Number of People
pivoted_df = mydf.pivot(index=['Year', 'Income Source', 'Ethnic Group'], columns='Measure', values='Value').reset_index()
pivoted_df.columns.name = None
pivoted_df = pivoted_df.drop(columns=['Average Weekly Income'])  # remove the avg weekly income column

# Apply filter to remove all income sources other than government funding
mask = pivoted_df['Income Source'].isin(['Government Transfer Income'])
filtered_df = pivoted_df[mask]

# %%
filtered_df
# Out:
#      Year               Income Source         Ethnic Group  \
# 7    2013  Government Transfer Income                Asian
# 8    2013  Government Transfer Income             European
# 9    2013  Government Transfer Income                MELAA
# 10   2013  Government Transfer Income                Maori
# 11   2013  Government Transfer Income      Other Ethnicity
# ..    ...                         ...                  ...
# 289  2023  Government Transfer Income                MELAA
# 290  2023  Government Transfer Income                Maori
# 291  2023  Government Transfer Income      Other Ethnicity
# 292  2023  Government Transfer Income      Pacific Peoples
# 293  2023  Government Transfer Income  Total Ethnic Groups
#
#      Median Weekly Income  Number of People (000)
# 7                   220.0                    95.6
# 8                   304.0                   861.7
# 9                   230.0                     8.2
# 10                  286.0                   192.8
# ...

# %%
# median_govt_incomes = pivoted_df.loc[(pivoted_df['Income Source'] == 'Government Transfer Income'), 'Median Weekly Income']
# median_govt_incomes

# %%
# Set the dependent and independent variables for MLR model
import numpy as np
dependent_variable = 'Median Weekly Income'
# independent_variables = ['Year', 'Ethnic Group', 'Number of People (000)']
independent_variables = ['Ethnic Group_European', 'Ethnic Group_MELAA', 'Ethnic Group_Maori', 
                         'Ethnic Group_Other Ethnicity', 'Ethnic Group_Pacific Peoples', 
                         'Ethnic Group_Total Ethnic Groups']
# onehotencode the ethnic groups so they can be used for training the model
mydf_encoded = pd.get_dummies(filtered_df, columns=['Ethnic Group'], drop_first=True)
# print(mydf_encoded)
x_train, x_test, y_train, y_test = train_test_split(mydf_encoded[dependent_variable], mydf_encoded[independent_variables], test_size=0.2, random_state=13)
x_train = np.array(x_train).reshape(-1, 1)
x_test = np.array(x_test).reshape(-1, 1)
# x_train = train_data.drop(columns=[dependent_variable, 'Income Source'])
# y_train = train_data[dependent_variable]
model = LinearRegression()
model.fit(x_train, y_train)

# Make predictions on the testing data
# x_test = test_data.drop(columns=[dependent_variable, 'Income Source'])
# y_test = test_data[dependent_variable]
y_pred = model.predict(x_test)

print(y_pred)
# print(x_test)

# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)
rmse = mse**0.5
print(f"Root Mean Squared Error: {rmse}")
# Out:
# [[ 0.16506217  0.10260436  0.16769519  0.18729253  0.10632267  0.18458147]
#  [ 0.258196   -0.02079723  0.17802273  0.29645525  0.03815045  0.2862993 ]
#  [ 0.00169628  0.3190629   0.14957967 -0.00418963  0.22590344  0.00615839]
#  [ 0.02612482  0.28669527  0.15228854  0.02444322  0.2080222   0.03283848]
#  [ 0.08872297  0.20375321  0.15923     0.09781488  0.16220153  0.1012062 ]
#  [ 0.07040156  0.22802893  0.15719835  0.07634025  0.17561246  0.08119614]
#  [ 0.25972278 -0.0228202   0.17819204  0.2982448   0.03703287  0.28796681]
#  [ 0.12689257  0.15317879  0.1634626   0.14255371  0.1342621   0.14289384]
#  [ 0.11773186  0.16531665  0.16244677  0.13181639  0.14096756  0.1328888 ]
#  [ 0.16506217  0.10260436  0.16769519  0.18729253  0.10632267  0.18458147]
#  [ 0.16658895  0.10058139  0.1678645   0.18908208  0.10520509  0.18624898]
#  [ 0.07040156  0.22802893  0.15719835  0.07634025  0.17561246  0.08119614]
# ...
